# %%
import gandula
from tqdm.auto import tqdm
import os
import sys
import pandas as pd
import numpy as np

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
sys.path.append(os.path.abspath("../src"))

# %%
from gandula_rating.data.eventsLoader import get_match_events

# %%
from dotenv import load_dotenv
import os

load_dotenv()
# Out:
# True

# %%
#get_match_events(32233)

api_url = os.getenv('api_url')
api_key = os.getenv('api_key')
events = gandula.get_match_events(
    match_id=4625, api_url=api_url, api_key=api_key
)
events
# Out:
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# File c:\Users\jllgo\OneDrive\Documentos\UFMG\SALab\Code\gandula-rating\.venv\Lib\site-packages\gql\transport\httpx.py:168, in _HTTPXTransport._raise_response_error(self, response, reason)
#     166 try:
#     167     # Raise a HTTPError if response status is 400 or higher
# --> 168     response.raise_for_status()
#     169 except httpx.HTTPStatusError as e:
#
# File c:\Users\jllgo\OneDrive\Documentos\UFMG\SALab\Code\gandula-rating\.venv\Lib\site-packages\httpx\_models.py:829, in Response.raise_for_status(self)
#     828 message = message.format(self, error_type=error_type)
# --> 829 raise HTTPStatusError(message, request=request, response=self)
#
# HTTPStatusError: Client error '401 Unauthorized' for url 'https://faraday.pff.com/api'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/401
#
# The above exception was the direct cause of the following exception:
#
# TransportServerError                      Traceback (most recent call last)
# File c:\Users\jllgo\OneDrive\Documentos\UFMG\SALab\Code\gandula-rating\.venv\Lib\site-packages\gandula\providers\pff\api\api_client.py:94, in execute_query(query, variables, client)
#      93 try:
# ---> 94     return client.execute(
#      95         gql(query),
#      96         variable_values=variables,
#      97         serialize_variables=True,
#      98         parse_result=True,
#      99     )
#     100 except Exception as exc:
#
# File c:\Users\jllgo\OneDrive\Documentos\UFMG\SALab\Code\gandula-rating\.venv\Lib\site-packages\gql\client.py:483, in Client.execute(self, document, variable_values, operation_name, serialize_variables, parse_result, get_execution_result, **kwargs)
#     482 else:  # Sync transports
# --> 483     return self.execute_sync(
#     484         document,
#     485         variable_values=variable_values,
#     486         operation_name=operation_name,
#     487         serialize_variables=serialize_variables,
#     488         parse_result=parse_result,
#     489         get_execution_result=get_execution_result,
#     490         **kwargs,
#     491     )
#
# File c:\Users\jllgo\OneDrive\Documentos\UFMG\SALab\Code\gandula-rating\.venv\Lib\site-packages\gql\client.py:247, in Client.execute_sync(self, document, variable_values, operation_name, serialize_variables, parse_result, get_execution_result, **kwargs)
#     246 with self as session:
# --> 247     return session.execute(
#     248         document,
#     249         variable_values=variable_values,
#     250         operation_name=operation_name,
#     251         serialize_variables=serialize_variables,
#     252         parse_result=parse_result,
#     253         get_execution_result=get_execution_result,
#     254         **kwargs,
#     255     )
#
# File c:\Users\jllgo\OneDrive\Documentos\UFMG\SALab\Code\gandula-rating\.venv\Lib\site-packages\gql\client.py:1016, in SyncClientSession.execute(self, document, variable_values, operation_name, serialize_variables, parse_result, get_execution_result, **kwargs)
#    1015 # Validate and execute on the transport
# -> 1016 result = self._execute(
#    1017     document,
#    1018     variable_values=variable_values,
#    1019     operation_name=operation_name,
#    1020     serialize_variables=serialize_variables,
#    1021     parse_result=parse_result,
#    1022     **kwargs,
#    1023 )
#    1025 # Raise an error if an error is returned in the ExecutionResult object
#
# File c:\Users\jllgo\OneDrive\Documentos\UFMG\SALab\Code\gandula-rating\.venv\Lib\site-packages\gql\client.py:925, in SyncClientSession._execute(self, document, variable_values, operation_name, serialize_variables, parse_result, **kwargs)
#     924 else:
# --> 925     result = self.transport.execute(
#     926         document,
#     927         variable_values=variable_values,
#     928         operation_name=operation_name,
#     929         **kwargs,
#     930     )
#     932 # Unserialize the result if requested
#
# File c:\Users\jllgo\OneDrive\Documentos\UFMG\SALab\Code\gandula-rating\.venv\Lib\site-packages\gql\transport\httpx.py:230, in HTTPXTransport.execute(self, document, variable_values, operation_name, extra_args, upload_files)
#     228 response = self.client.post(self.url, **post_args)
# --> 230 return self._prepare_result(response)
#
# File c:\Users\jllgo\OneDrive\Documentos\UFMG\SALab\Code\gandula-rating\.venv\Lib\site-packages\gql\transport\httpx.py:154, in _HTTPXTransport._prepare_result(self, response)
#     153 if "errors" not in result and "data" not in result:
# --> 154     self._raise_response_error(response, 'No "data" or "errors" keys in answer')
#     156 return ExecutionResult(
#     157     errors=result.get("errors"),
#     158     data=result.get("data"),
#     159     extensions=result.get("extensions"),
#     160 )
#
# File c:\Users\jllgo\OneDrive\Documentos\UFMG\SALab\Code\gandula-rating\.venv\Lib\site-packages\gql\transport\httpx.py:170, in _HTTPXTransport._raise_response_error(self, response, reason)
#     169 except httpx.HTTPStatusError as e:
# --> 170     raise TransportServerError(str(e), e.response.status_code) from e
#     172 raise TransportProtocolError(
#     173     f"Server did not return a GraphQL result: " f"{reason}: " f"{response.text}"
#     174 )
#
# TransportServerError: Client error '401 Unauthorized' for url 'https://faraday.pff.com/api'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/401
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# File c:\Users\jllgo\OneDrive\Documentos\UFMG\SALab\Code\gandula-rating\.venv\Lib\site-packages\gandula\api\match.py:25, in get_match_events(match_id, api_url, api_key)
#      24 try:
# ---> 25     events = match.get_match_events(
#      26         match_id, pff_api_url=api_url, pff_api_key=api_key
#      27     )
#      28     return [PFF_Event.model_validate(event) for event in events['gameEvents']]
#
# File c:\Users\jllgo\OneDrive\Documentos\UFMG\SALab\Code\gandula-rating\.venv\Lib\site-packages\gandula\providers\pff\api\match.py:11, in get_match_events(match_id, pff_api_url, pff_api_key)
#      10 client = get_client(pff_api_url, pff_api_key)
# ---> 11 return execute_query(query, variables, client=client)
#
# File c:\Users\jllgo\OneDrive\Documentos\UFMG\SALab\Code\gandula-rating\.venv\Lib\site-packages\gandula\providers\pff\api\api_client.py:101, in execute_query(query, variables, client)
#     100 except Exception as exc:
# --> 101     raise Exception(
#     102         f'There was an error trying to execute the following query:\n'
#     103         f'Query: {query}\n'
#     104         f'Variables: {variables}'
#     105     ) from exc
#
# Exception: There was an error trying to execute the following query:
# Query: fragment LocationFragment on Location{eventModule id name x y}fragment TeamFragment on Team{id name shortName}fragment CrossEventFragment on CrossEvent{ballHeightType blockerPlayer{...PlayerFragment}clearerPlayer{...PlayerFragment}completeToPlayer{...PlayerFragment}createsSpace crossEndPointX crossEndPointY crossHighPointType crossOutcomeType crossPointX crossPointY crossStartPointX crossStartPointY crossType crossZoneType crosserBodyType crosserPlayer{...PlayerFragment}defenderBallHeightType defenderBodyType defenderPlayer{...PlayerFragment}deflectionPointX deflectionPointY deflectorBodyType deflectorPlayer{...PlayerFragment}failedInterventionPlayer{...PlayerFragment}failedInterventionPlayer1{...PlayerFragment}failedInterventionPlayer2{...PlayerFragment}failedInterventionPlayer3{...PlayerFragment}failedInterventionPointX failedInterventionPointY game{id}gameEvent{id}goalkeeperPointX goalkeeperPointY id incompletionReasonType intendedTargetPlayer{...PlayerFragment}intendedTargetPointX intendedTargetPointY keeperPlayer{...PlayerFragment}linesBrokenType missedTouchPlayer{...PlayerFragment}missedTouchPointX missedTouchPointY missedTouchType noLook opportunityType possessionEvent{id}pressurePlayer{...PlayerFragment}pressureType receiverBallHeightType receiverBodyType receiverPointX receiverPointY secondIncompletionReasonType shotInitialHeightType shotOutcomeType targetZonePointX targetZonePointY}fragment PossessionEventFragment on PossessionEvent{id ballCarryEvent{...BallCarryEventFragment}challengeEvent{...ChallengeEventFragment}clearanceEvent{...ClearanceEventFragment}crossEvent{...CrossEventFragment}defenders{...DefenderFragment}duration endTime formattedGameClock fouls{...FoulFragment}game{id}gameClock gameEvent{id}insertedAt lastInGameEvent passingEvent{...PassingEventFragment}possessionEventType reboundEvent{...ReboundEventFragment}shootingEvent{...ShootingEventFragment}startTime updatedAt videoUrl}fragment PassingEventFragment on PassingEvent{ballHeightType blockerPlayer{...PlayerFragment}clearerPlayer{...PlayerFragment}createsSpace defenderBodyType defenderHeightType defenderPlayer{...PlayerFragment}defenderPointX defenderPointY deflectionPointX deflectionPointY deflectorBodyType deflectorPlayer{...PlayerFragment}failedInterventionPlayer{...PlayerFragment}failedInterventionPlayer1{...PlayerFragment}failedInterventionPlayer2{...PlayerFragment}failedInterventionPlayer3{...PlayerFragment}failedInterventionPointX failedInterventionPointY game{id}gameEvent{id}goalkeeperPointX goalkeeperPointY id incompletionReasonType keeperPlayer{...PlayerFragment}linesBrokenType missedTouchPlayer{...PlayerFragment}missedTouchPointX missedTouchPointY missedTouchType noLook onTarget opportunityType outOfPlayPointX outOfPlayPointY passAccuracyType passBodyType passHighPointType passOutcomeType passPointX passPointY passType passerPlayer{...PlayerFragment}possessionEvent{id}pressurePlayer{...PlayerFragment}pressureType receiverBodyType receiverFacingType receiverHeightType receiverPlayer{...PlayerFragment}receiverPointX receiverPointY secondIncompletionReasonType shotInitialHeightType shotOutcomeType targetFacingType targetPlayer{...PlayerFragment}targetPointX targetPointY}fragment PlayerFragment on Player{id}fragment BallCarryEventFragment on BallCarryEvent{additionalChallenger1{...PlayerFragment}additionalChallenger2{...PlayerFragment}additionalChallenger3{...PlayerFragment}ballCarrierPlayer{...PlayerFragment}ballCarryEndPointX ballCarryEndPointY ballCarryStartPointX ballCarryStartPointY ballCarryType carryType challengerPlayer{...PlayerFragment}createsSpace defenderPlayer{...PlayerFragment}defenderPointX defenderPointY dribbleEndPointX dribbleEndPointY dribbleOutcomeType dribbleStartPointX dribbleStartPointY dribbleType game{id}gameEvent{id}id linesBrokenType missedTouchPlayer{...PlayerFragment}missedTouchPointX missedTouchPointY missedTouchType opportunityType possessionEvent{id}pressurePlayer{...PlayerFragment}tackleAttemptPointX tack ...
# Variables: {'gameId': 4625}
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[26], line 5
#       3 api_url = os.getenv('api_url')
#       4 api_key = os.getenv('api_key')
# ----> 5 events = gandula.get_match_events(
#       6     match_id=4625, api_url=api_url, api_key=api_key
#       7 )
#       8 events
#
# File c:\Users\jllgo\OneDrive\Documentos\UFMG\SALab\Code\gandula-rating\.venv\Lib\site-packages\gandula\api\match.py:30, in get_match_events(match_id, api_url, api_key)
#      28     return [PFF_Event.model_validate(event) for event in events['gameEvents']]
#      29 except Exception as exc:
# ---> 30     raise Exception(f'Error getting match events for match_id={match_id}') from exc
#
# Exception: Error getting match events for match_id=4625

# %%
from gandula.providers.pff.api.api_client import execute_query, get_client

api_url = os.getenv('api_url')
api_key = os.getenv('api_key')
client = get_client(api_url, api_key)

# %%
query = """
query possessionEvents(
  $gameId: ID!,
  $possessionEventType: PossessionEventType,
  $sortField: PossessionEventSortFields,
  $sortOrder: SortOrder
) {
  possessionEvents(
    gameId: $gameId,
    possessionEventType: $possessionEventType,
    sortField: $sortField,
    sortOrder: $sortOrder
  ) {
    duration
    endTime
    formattedGameClock
    gameClock
    id
    insertedAt
    lastInGameEvent
    period
    possessionEventType
    startTime
    updatedAt
    videoUrl
  }
}
"""

variables = {
  "gameId": 4625,
  "possessionEventType": "BC",
  "sortField": "ID",
  "sortOrder": "ASC"
}

client.execute(
         gql(query),
         variable_values=variables,
         serialize_variables=True,
         parse_result=True,
     )
# Out:
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# File c:\Users\jllgo\OneDrive\Documentos\UFMG\SALab\Code\gandula-rating\.venv\Lib\site-packages\gql\transport\httpx.py:168, in _HTTPXTransport._raise_response_error(self, response, reason)
#     166 try:
#     167     # Raise a HTTPError if response status is 400 or higher
# --> 168     response.raise_for_status()
#     169 except httpx.HTTPStatusError as e:
#
# File c:\Users\jllgo\OneDrive\Documentos\UFMG\SALab\Code\gandula-rating\.venv\Lib\site-packages\httpx\_models.py:829, in Response.raise_for_status(self)
#     828 message = message.format(self, error_type=error_type)
# --> 829 raise HTTPStatusError(message, request=request, response=self)
#
# HTTPStatusError: Client error '401 Unauthorized' for url 'https://faraday.pff.com/api'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/401
#
# The above exception was the direct cause of the following exception:
#
# TransportServerError                      Traceback (most recent call last)
# File c:\Users\jllgo\OneDrive\Documentos\UFMG\SALab\Code\gandula-rating\.venv\Lib\site-packages\gandula\providers\pff\api\api_client.py:94, in execute_query(query, variables, client)
#      93 try:
# ---> 94     return client.execute(
#      95         gql(query),
#      96         variable_values=variables,
#      97         serialize_variables=True,
#      98         parse_result=True,
#      99     )
#     100 except Exception as exc:
#
# File c:\Users\jllgo\OneDrive\Documentos\UFMG\SALab\Code\gandula-rating\.venv\Lib\site-packages\gql\client.py:483, in Client.execute(self, document, variable_values, operation_name, serialize_variables, parse_result, get_execution_result, **kwargs)
#     482 else:  # Sync transports
# --> 483     return self.execute_sync(
#     484         document,
#     485         variable_values=variable_values,
#     486         operation_name=operation_name,
#     487         serialize_variables=serialize_variables,
#     488         parse_result=parse_result,
#     489         get_execution_result=get_execution_result,
#     490         **kwargs,
#     491     )
#
# File c:\Users\jllgo\OneDrive\Documentos\UFMG\SALab\Code\gandula-rating\.venv\Lib\site-packages\gql\client.py:247, in Client.execute_sync(self, document, variable_values, operation_name, serialize_variables, parse_result, get_execution_result, **kwargs)
#     246 with self as session:
# --> 247     return session.execute(
#     248         document,
#     249         variable_values=variable_values,
#     250         operation_name=operation_name,
#     251         serialize_variables=serialize_variables,
#     252         parse_result=parse_result,
#     253         get_execution_result=get_execution_result,
#     254         **kwargs,
#     255     )
#
# File c:\Users\jllgo\OneDrive\Documentos\UFMG\SALab\Code\gandula-rating\.venv\Lib\site-packages\gql\client.py:1016, in SyncClientSession.execute(self, document, variable_values, operation_name, serialize_variables, parse_result, get_execution_result, **kwargs)
#    1015 # Validate and execute on the transport
# -> 1016 result = self._execute(
#    1017     document,
#    1018     variable_values=variable_values,
#    1019     operation_name=operation_name,
#    1020     serialize_variables=serialize_variables,
#    1021     parse_result=parse_result,
#    1022     **kwargs,
#    1023 )
#    1025 # Raise an error if an error is returned in the ExecutionResult object
#
# File c:\Users\jllgo\OneDrive\Documentos\UFMG\SALab\Code\gandula-rating\.venv\Lib\site-packages\gql\client.py:925, in SyncClientSession._execute(self, document, variable_values, operation_name, serialize_variables, parse_result, **kwargs)
#     924 else:
# --> 925     result = self.transport.execute(
#     926         document,
#     927         variable_values=variable_values,
#     928         operation_name=operation_name,
#     929         **kwargs,
#     930     )
#     932 # Unserialize the result if requested
#
# File c:\Users\jllgo\OneDrive\Documentos\UFMG\SALab\Code\gandula-rating\.venv\Lib\site-packages\gql\transport\httpx.py:230, in HTTPXTransport.execute(self, document, variable_values, operation_name, extra_args, upload_files)
#     228 response = self.client.post(self.url, **post_args)
# --> 230 return self._prepare_result(response)
#
# File c:\Users\jllgo\OneDrive\Documentos\UFMG\SALab\Code\gandula-rating\.venv\Lib\site-packages\gql\transport\httpx.py:154, in _HTTPXTransport._prepare_result(self, response)
#     153 if "errors" not in result and "data" not in result:
# --> 154     self._raise_response_error(response, 'No "data" or "errors" keys in answer')
#     156 return ExecutionResult(
#     157     errors=result.get("errors"),
#     158     data=result.get("data"),
#     159     extensions=result.get("extensions"),
#     160 )
#
# File c:\Users\jllgo\OneDrive\Documentos\UFMG\SALab\Code\gandula-rating\.venv\Lib\site-packages\gql\transport\httpx.py:170, in _HTTPXTransport._raise_response_error(self, response, reason)
#     169 except httpx.HTTPStatusError as e:
# --> 170     raise TransportServerError(str(e), e.response.status_code) from e
#     172 raise TransportProtocolError(
#     173     f"Server did not return a GraphQL result: " f"{reason}: " f"{response.text}"
#     174 )
#
# TransportServerError: Client error '401 Unauthorized' for url 'https://faraday.pff.com/api'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/401
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# File c:\Users\jllgo\OneDrive\Documentos\UFMG\SALab\Code\gandula-rating\.venv\Lib\site-packages\gandula\api\match.py:25, in get_match_events(match_id, api_url, api_key)
#      24 try:
# ---> 25     events = match.get_match_events(
#      26         match_id, pff_api_url=api_url, pff_api_key=api_key
#      27     )
#      28     return [PFF_Event.model_validate(event) for event in events['gameEvents']]
#
# File c:\Users\jllgo\OneDrive\Documentos\UFMG\SALab\Code\gandula-rating\.venv\Lib\site-packages\gandula\providers\pff\api\match.py:11, in get_match_events(match_id, pff_api_url, pff_api_key)
#      10 client = get_client(pff_api_url, pff_api_key)
# ---> 11 return execute_query(query, variables, client=client)
#
# File c:\Users\jllgo\OneDrive\Documentos\UFMG\SALab\Code\gandula-rating\.venv\Lib\site-packages\gandula\providers\pff\api\api_client.py:101, in execute_query(query, variables, client)
#     100 except Exception as exc:
# --> 101     raise Exception(
#     102         f'There was an error trying to execute the following query:\n'
#     103         f'Query: {query}\n'
#     104         f'Variables: {variables}'
#     105     ) from exc
#
# Exception: There was an error trying to execute the following query:
# Query: fragment LocationFragment on Location{eventModule id name x y}fragment TeamFragment on Team{id name shortName}fragment CrossEventFragment on CrossEvent{ballHeightType blockerPlayer{...PlayerFragment}clearerPlayer{...PlayerFragment}completeToPlayer{...PlayerFragment}createsSpace crossEndPointX crossEndPointY crossHighPointType crossOutcomeType crossPointX crossPointY crossStartPointX crossStartPointY crossType crossZoneType crosserBodyType crosserPlayer{...PlayerFragment}defenderBallHeightType defenderBodyType defenderPlayer{...PlayerFragment}deflectionPointX deflectionPointY deflectorBodyType deflectorPlayer{...PlayerFragment}failedInterventionPlayer{...PlayerFragment}failedInterventionPlayer1{...PlayerFragment}failedInterventionPlayer2{...PlayerFragment}failedInterventionPlayer3{...PlayerFragment}failedInterventionPointX failedInterventionPointY game{id}gameEvent{id}goalkeeperPointX goalkeeperPointY id incompletionReasonType intendedTargetPlayer{...PlayerFragment}intendedTargetPointX intendedTargetPointY keeperPlayer{...PlayerFragment}linesBrokenType missedTouchPlayer{...PlayerFragment}missedTouchPointX missedTouchPointY missedTouchType noLook opportunityType possessionEvent{id}pressurePlayer{...PlayerFragment}pressureType receiverBallHeightType receiverBodyType receiverPointX receiverPointY secondIncompletionReasonType shotInitialHeightType shotOutcomeType targetZonePointX targetZonePointY}fragment PossessionEventFragment on PossessionEvent{id ballCarryEvent{...BallCarryEventFragment}challengeEvent{...ChallengeEventFragment}clearanceEvent{...ClearanceEventFragment}crossEvent{...CrossEventFragment}defenders{...DefenderFragment}duration endTime formattedGameClock fouls{...FoulFragment}game{id}gameClock gameEvent{id}insertedAt lastInGameEvent passingEvent{...PassingEventFragment}possessionEventType reboundEvent{...ReboundEventFragment}shootingEvent{...ShootingEventFragment}startTime updatedAt videoUrl}fragment PassingEventFragment on PassingEvent{ballHeightType blockerPlayer{...PlayerFragment}clearerPlayer{...PlayerFragment}createsSpace defenderBodyType defenderHeightType defenderPlayer{...PlayerFragment}defenderPointX defenderPointY deflectionPointX deflectionPointY deflectorBodyType deflectorPlayer{...PlayerFragment}failedInterventionPlayer{...PlayerFragment}failedInterventionPlayer1{...PlayerFragment}failedInterventionPlayer2{...PlayerFragment}failedInterventionPlayer3{...PlayerFragment}failedInterventionPointX failedInterventionPointY game{id}gameEvent{id}goalkeeperPointX goalkeeperPointY id incompletionReasonType keeperPlayer{...PlayerFragment}linesBrokenType missedTouchPlayer{...PlayerFragment}missedTouchPointX missedTouchPointY missedTouchType noLook onTarget opportunityType outOfPlayPointX outOfPlayPointY passAccuracyType passBodyType passHighPointType passOutcomeType passPointX passPointY passType passerPlayer{...PlayerFragment}possessionEvent{id}pressurePlayer{...PlayerFragment}pressureType receiverBodyType receiverFacingType receiverHeightType receiverPlayer{...PlayerFragment}receiverPointX receiverPointY secondIncompletionReasonType shotInitialHeightType shotOutcomeType targetFacingType targetPlayer{...PlayerFragment}targetPointX targetPointY}fragment PlayerFragment on Player{id}fragment BallCarryEventFragment on BallCarryEvent{additionalChallenger1{...PlayerFragment}additionalChallenger2{...PlayerFragment}additionalChallenger3{...PlayerFragment}ballCarrierPlayer{...PlayerFragment}ballCarryEndPointX ballCarryEndPointY ballCarryStartPointX ballCarryStartPointY ballCarryType carryType challengerPlayer{...PlayerFragment}createsSpace defenderPlayer{...PlayerFragment}defenderPointX defenderPointY dribbleEndPointX dribbleEndPointY dribbleOutcomeType dribbleStartPointX dribbleStartPointY dribbleType game{id}gameEvent{id}id linesBrokenType missedTouchPlayer{...PlayerFragment}missedTouchPointX missedTouchPointY missedTouchType opportunityType possessionEvent{id}pressurePlayer{...PlayerFragment}tackleAttemptPointX tack ...
# Variables: {'gameId': 10517}
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 gandula.get_match_events(10517)
#
# File c:\Users\jllgo\OneDrive\Documentos\UFMG\SALab\Code\gandula-rating\.venv\Lib\site-packages\gandula\api\match.py:30, in get_match_events(match_id, api_url, api_key)
#      28     return [PFF_Event.model_validate(event) for event in events['gameEvents']]
#      29 except Exception as exc:
# ---> 30     raise Exception(f'Error getting match events for match_id={match_id}') from exc
#
# Exception: Error getting match events for match_id=10517
