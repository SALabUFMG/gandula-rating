# %%
import gandula
from tqdm.auto import tqdm
import os
import sys
import pandas as pd
import numpy as np

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
sys.path.append(os.path.abspath("../src"))

# %%
import numpy
print(numpy.__version__)
# Out:
# 1.26.4

# %%
from gandula_rating.data.eventsLoader import get_match_events
from gandula_rating.data.spadlLoader import get_spadl_actions

# %%
from dotenv import load_dotenv
import os

load_dotenv()
# Out:
# True

# %%
#get_match_events(32233)

api_url = os.getenv('api_url')
api_key = os.getenv('api_key')
events = gandula.get_match_events(
    match_id=4625, api_url=api_url, api_key=api_key
)
events
# Out:
# [PFF_Event(6911618) [PFF_PossessionEventType.PASS=6801909],
#  PFF_Event(6911620) [PFF_PossessionEventType.PASS=6801911],
#  PFF_Event(6911624) [PFF_PossessionEventType.PASS=6801915],
#  PFF_Event(6911636) [PFF_PossessionEventType.PASS=6801926],
#  PFF_Event(6911648) [PFF_PossessionEventType.CHALLENGE=6801936, PFF_PossessionEventType.PASS=6801937],
#  PFF_Event(6911656) [PFF_PossessionEventType.CLEARANCE=6821563],
#  PFF_Event(6911659) [],
#  PFF_Event(6911665) [PFF_PossessionEventType.PASS=6801954],
#  PFF_Event(6911669) [],
#  PFF_Event(6911672) [PFF_PossessionEventType.PASS=6801960],
#  PFF_Event(6911677) [PFF_PossessionEventType.PASS=6801965],
#  PFF_Event(6911680) [],
#  PFF_Event(6911684) [PFF_PossessionEventType.CHALLENGE=6801972, PFF_PossessionEventType.CLEARANCE=6801973],
#  PFF_Event(6911687) [PFF_PossessionEventType.PASS=6801976],
#  PFF_Event(6911688) [PFF_PossessionEventType.PASS=6801979],
#  PFF_Event(6911690) [],
# ...

# %%
get_spadl_actions()
# Out:
#      game_id                     original_event_id  period_id  time_seconds  \
# 0       None  549567bd-36de-4ac8-b8dc-6b5d3f1e4be8          1        0.5750
# 1       None  4e4e4cad-9897-43ec-842d-585a4077f6ce          1        3.8640
# 2       None  be27cc25-92b5-4696-b43c-aad957a6119a          1        7.1520
# 3       None  b33c0b7f-7456-4efe-b43c-5fd7cbd14689          1        8.8480
# 4       None  c587e5ce-fe6e-4cfb-b510-8a8e193699d3          1       10.8730
# ...      ...                                   ...        ...           ...
# 1590    None                                   NaN          2     2793.5735
# 1591    None  67a741f9-b9fa-4fb5-a97b-8c81a41f8e44          2     2795.4200
# 1592    None                                   NaN          2     2797.2655
# 1593    None  06de67c7-39d8-4307-a475-5db72ba70891          2     2799.1110
# 1594    None  036c1a04-8d9b-40c0-8b35-780df67fab4d          2     2803.0320
#
# ...
